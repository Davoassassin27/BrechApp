# %% [markdown]
# # DolarApi Exploration
#
# This notebook explores the data returned by DolarApi.com.

# %%
import sys
import os
# Add src to path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from ingestion.api_client import APIClient

# %%
client = APIClient()
df = client.get_as_dataframe()
df.head()
# Out:
#   moneda             casa                   nombre  compra   venta  \
# 0    USD          oficial                  Oficial  1425.0  1475.0
# 1    USD             blue                     Blue  1415.0  1435.0
# 2    USD            bolsa                    Bolsa  1473.7  1482.9
# 3    USD  contadoconliqui  Contado con liquidación  1515.2  1516.1
# 4    USD        mayorista                Mayorista  1442.5  1451.5
#
#          fechaActualizacion
# 0  2025-11-28T17:03:00.000Z
# 1  2025-11-30T18:01:00.000Z
# 2  2025-11-30T18:01:00.000Z
# 3  2025-11-30T18:01:00.000Z
# 4  2025-11-28T15:47:00.000Z

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   moneda              7 non-null      object
#  1   casa                7 non-null      object
#  2   nombre              7 non-null      object
#  3   compra              7 non-null      float64
#  4   venta               7 non-null      float64
#  5   fechaActualizacion  7 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 468.0+ bytes
